# %%
# !pip install torch
# !pip install opencv-python
# !pip install ultralytics
import torch
import cv2
from ultralytics import YOLO

# %%
model = YOLO('../yolov8n.pt')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cpu

# %%
model.to(device)

# %%
classes = model.names
classes
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
# ...

# %%
# cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture('../walking peoples.mp4')


fourcc = cv2.VideoWriter_fourcc(*'MJPG')
out = cv2.VideoWriter('../output_video.mp4', fourcc, 24, (1280, 720))

while cap.isOpened():
    success, img = cap.read()
    if not success:
        cap.release()
        cv2.destroyAllWindows()
        break
    width = img.shape[1]
    height = img.shape[0]

    results = model(img)
    for result in results:
        objects = result.boxes.cls
        bboxes = result.boxes.xyxyn
        confidences = result.boxes.conf
        for obj, box, conf in zip(objects, bboxes, confidences):
            conf = conf.tolist()
            if conf < 0.3:
                continue
            conf = int(conf * 100)
            x1, y1 = int(box[0] * width), int(box[1] * height)
            x2, y2 = int(box[2] * width), int(box[3] * height)
            label = classes[obj.tolist()]
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            text = f'{label} ({conf})%'
            cv2.putText(img, text, (x1, y1+30), cv2.FONT_HERSHEY_PLAIN, 2, (0, 255, 0), 1)
    out.write(img)
    cv2.imshow('image', img)

    if cv2.waitKey(1) & 0xff == 27:
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# 0: 384x640 22 persons, 2 handbags, 1 suitcase, 92.2ms
# Speed: 2.6ms preprocess, 92.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 handbags, 1 suitcase, 82.0ms
# Speed: 1.7ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 4 handbags, 1 suitcase, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 1 suitcase, 89.6ms
# Speed: 2.0ms preprocess, 89.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 3 handbags, 79.9ms
# Speed: 2.0ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 1 suitcase, 94.0ms
# Speed: 1.9ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 car, 3 handbags, 1 suitcase, 86.2ms
# ...
